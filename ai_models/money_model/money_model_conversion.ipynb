# %% [markdown]
# # 🚀 YOLOv8 Model Magic: From PyTorch to Mobile & Web!
#
# Alright, here’s what just went down in this notebook:
#
# We took our trusty YOLOv8 model (`best.pt`) — fresh from PyTorch land — and waved some ultralytics wizardry to transform it into two shiny new formats:
#
# - 🏃‍♂️ **TensorFlow Lite (TFLite)** — perfect for running super fast on phones and edge devices.
# - 🌐 **TensorFlow.js (TFJS)** — ready to power its stuff directly inside your web browser, no installs required!
#
# Once the model got its new outfits, we packed up the web model folder into a neat zip and grabbed the TFLite file so you can take them wherever you want.

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load your model
model = YOLO('best.pt')

# Export to multiple formats
# Supported formats: ['onnx', 'engine', 'tf', 'tflite', 'torchscript', 'coreml', 'python', 'saved_model', 'pb', 'openvino', 'edgetpu', 'tfjs']
model.export(format='tflite')  # For TensorFlow Lite
model.export(format='tfjs')    # For TensorFlow.js
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0,<1.4.0', 'onnx>=1.12.0,<1.18.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.59', 'onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 5.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip'...
# 100%|██████████| 1.11M/1.11M [00:00<00:00, 28.7MB/s]
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/calibration_image_sample_data_20x128x128x3_float32.npy...: 100%|██████████| 1/1 [00:00<00:00, 40.38file/s]
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.61...
# ONNX: export success ✅ 5.4s, saved as 'best.onnx' (11.7 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.2...
# Saved artifact at 'best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 9, 8400), dtype=tf.float32, name=None)
# Captures:
#   132965764003984: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132965764003600: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   132965764004368: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   132965754195216: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132965754194448: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   132965754194064: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965764003408: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   132965754194640: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965754195792: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754195600: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754198096: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   132965754198480: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   132965754191952: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   132965754195408: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   132965754195984: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754196176: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754196752: TensorSpec(shape=(1, 1, 48, 32), dtype=tf.float32, name=None)
#   132965754198864: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965754199056: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132965754197136: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   132965754197328: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754199248: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   132965754199632: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754200208: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754200016: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754200976: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132965754202320: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965754199824: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132965754199440: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965754202704: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132965754202512: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965754201168: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132965754201744: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965754200400: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754200592: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754203280: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   132965754203088: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754203472: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132965754201552: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   132965754202896: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965754203664: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   132965754204240: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965754204624: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754204432: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754205392: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754206736: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754204048: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754203856: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754207120: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754206928: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754205584: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754206160: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754204816: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754205008: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754207696: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   132965754207504: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965754207888: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132965754205968: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   132965754207312: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132965754208080: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   132965617287440: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132965617288016: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965617287824: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965617288784: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132965617290128: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965617287632: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132965617287248: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965617288208: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965617288400: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965617290320: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   132965617290512: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132965617288976: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   132965617289552: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965617290896: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   132965617290704: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132965763997648: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   132965764004752: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965763996880: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965763992656: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965802027984: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965802028752: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965763999760: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965764005520: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965763998032: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965763999952: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965764004176: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   132965763999376: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965764000144: TensorSpec(shape=(1, 1, 192, 64), dtype=tf.float32, name=None)
#   132965763996688: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965800968848: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965800969616: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965763999184: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132965800970192: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965800968464: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132965800969424: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965800968656: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965800969040: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965800968272: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   132965617291856: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965617292048: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132965617292240: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965617291472: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965617293584: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   132965617294352: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965617295504: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965617295120: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965
TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754199440: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754199824: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754201744: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132965754202896: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965754202320: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132965754198864: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132965754202704: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754202512: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754204240: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   132965754203280: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754203088: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132965754203664: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754200400: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754205584: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   132965754206160: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965754207312: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754207888: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754208080: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754194256: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754202128: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754201936: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754206544: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754206352: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965754196944: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   132965754201360: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965754192144: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132965754205968: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132965754205200: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965764003600: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   132965764004368: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132965764005520: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965763992656: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965763998032: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132965764004944: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965764000336: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132965764000528: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132965763999952: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965764004176: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132965764000144: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   132965763996688: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132965764004560: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   132965763999760: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   132965754196368: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   132965754195024: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   132965754205392: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754204624: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965801176208: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965763998992: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754194832: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754193488: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754206736: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754204432: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965801176400: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965801177936: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754193296: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754193872: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754204048: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965754203856: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132965801173520: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965801177360: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965764003984: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754193680: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754207120: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754206928: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965801174672: TensorSpec(shape=(1, 1, 64, 5), dtype=tf.float32, name=None)
#   132965801173328: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   132965764003408: TensorSpec(shape=(1, 1, 64, 5), dtype=tf.float32, name=None)
#   132965763996880: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   132965754204816: TensorSpec(shape=(1, 1, 64, 5), dtype=tf.float32, name=None)
#   132965754207504: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   132965801173712: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965801174096: TensorSpec(shape=(5,), dtype=tf.float32, name=None)
#   132965763997648: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965764004752: TensorSpec(shape=(5,), dtype=tf.float32, name=None)
#   132965754205008: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132965754207696: TensorSpec(shape=(5,), dtype=tf.float32, name=None)
#   132965801166416: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132965801165840: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132965801166800: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   132965801165648: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132965801167376: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132965801169104: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132965801173904: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132965801169296: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   132965801172560: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   132965801165456: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132965801165264: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
# TensorFlow SavedModel: export success ✅ 16.5s, saved as 'best_saved_model' (29.3 MB)
#
# TensorFlow GraphDef: starting export with tensorflow 2.18.0...
# TensorFlow GraphDef: export success ✅ 1.8s, saved as 'best.pb' (11.7 MB)
# requirements: Ultralytics requirement ['tensorflowjs'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 0.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>
# TensorFlow.js: starting export with tensorflowjs 4.22.0...
#
# TensorFlow.js: output node names: Identity:0
# TensorFlow.js: running 'tensorflowjs_converter --input_format=tf_frozen_model  --output_node_names=Identity:0 "best.pb" "best_web_model"'
# TensorFlow.js: export success ✅ 9.4s, saved as 'best_web_model' (11.8 MB)
#
# Export complete (28.4s)
# Results saved to /content
# Predict:         yolo predict task=detect model=best_web_model imgsz=640
# Validate:        yolo val task=detect model=best_web_model imgsz=640 data=/content/Jordan-Coins-Detection-5/data.yaml
# Visualize:       https://netron.app
# 'best_web_model'

# %%
from google.colab import files

files.download('/content/best_saved_model/best_float32.tflite')

# %%
# !zip -r best_web_model.zip best_web_model
# Out:
#   adding: best_web_model/ (stored 0%)
#   adding: best_web_model/metadata.yaml (deflated 39%)
#   adding: best_web_model/group1-shard3of3.bin (deflated 7%)
#   adding: best_web_model/model.json (deflated 95%)
#   adding: best_web_model/group1-shard1of3.bin (deflated 11%)
#   adding: best_web_model/group1-shard2of3.bin (deflated 7%)

# %%
from google.colab import files
files.download('best_web_model_money.zip')
